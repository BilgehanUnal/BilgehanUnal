# %% [markdown]
# <a href="https://colab.research.google.com/github/BilgehanUnal/BilgehanUnal/blob/main/Bilgehan_task_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %% [markdown]
# # **Sentiment Analysis**

# %%
# Model
mdlSnt = pipeline('sentiment-analysis')

# Parameters
prmStatement = [' what can i do, sometimes. it is the football, that is the football. something happened everything is something happened.']# quated from Fatih Terim :D I want to confuse the prediciton
# Predict
mdlSnt(prmStatement)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
# Model
mdlSnt = pipeline('sentiment-analysis')

# Parameters
prmStatement = ['When something is positive, it does matter for negative people ']
# Predict
mdlSnt(prmStatement)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.8379164934158325}]

# %%
# Model
mdlSnt = pipeline('sentiment-analysis')

# Parameters
#prmStatement = 'We are happy to go on vacation this spring break.'
prmStatement = ['No, emptiness is not nothingness. Emptiness is a type of existence. You must use this existential emptiness to fill yourself']
# Predict
mdlSnt(prmStatement)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'NEGATIVE', 'score': 0.9903706908226013}]

# %% [markdown]
# # **Question Answering**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import pipeline
mdlQa = pipeline("question-answering")

# Parameters
f = open("/content/drive/MyDrive/Data/Three_Body_Problem.txt", "r")

context = f.read()

#The universe is a dark forest. Every civilization is an armed hunter stalking through the trees like a ghost,
#gently pushing aside branches that block the path and trying to tread without sound. Even breathing is done with
#care. The hunter has to be careful, because everywhere in the forest are stealthy hunters like him. If he finds
#other life—another hunter, an angel or a demon, a delicate infant or a tottering old man, a fairy or a
#demigod—there’s only one thing he can do: open fire and eliminate them. In this forest, hell is other people.
#An eternal threat that any life that exposes its own existence will be swiftly wiped out. This is the picture
#of cosmic civilization.






# Model
mdlQa = pipeline("question-answering")

# Parameters
question = "What is the picture of cosmic civilization?"

# Predict
answer = mdlQa(question=question, context=context)

# Print the result
print("Answer:", answer["answer"])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Answer: any life that exposes its own existence will be swiftly wiped out

# %%
# Load a pre-trained BART model for summarization
summarizer = pipeline('summarization', model='facebook/bart-large-cnn')


# Perform summarization
summary = summarizer(context, max_length=50, min_length=25, do_sample=False)

# Print summary
print(summary[0]['summary_text'])
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# The universe is a dark forest. Every civilization is an armed hunter stalking through the trees like a ghost. In this forest, hell is other people. An eternal threat that any life that exposes its own existence will be swiftly wiped out.

# %%
# Load a pre-trained model for zero-shot classification
classifier = pipeline('zero-shot-classification')

# Example text and candidate labels
candidate_labels = ["universe", "civilization", "hunter"]

# Perform classification
result = classifier(context, candidate_labels)

# Print results
print(result)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# model.safetensors:  95%|#########4| 1.54G/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # **Translator**

# %%
from transformers import pipeline

translator = pipeline('translation_en_to_fr')

# Example text
text = "It was one of the best courses I have ever taken. I am very happy to have taken this course as my last industry course at school. Thank you very much for teaching me."

# Perform translation
translation = translator(text, max_length=40)

# Print translation
print(translation[0]['translation_text'])
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision 686f1db (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your input_length: 44 is bigger than 0.9 * max_length: 40. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# C'était l'un des cours les plus utiles que j'ai jamais suivis. Je suis très heureux d'avoir suivi ce cours en tant que dernier
